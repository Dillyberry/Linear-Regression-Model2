# %% [markdown]
# ##Group_9_Assignment
# #Fadilat Saliu
# #Jumaih Barakat
# #Jane Akinyele
# #Agbaje Kemisola
# #Lynn Kamau
# #Mariam Williams
# #Jecolia Mengesha
# #Radwa Hosny

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df =pd.read_csv('/content/drive/MyDrive/Colab Notebooks/carprices 3 - carprices 3.csv')
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
#drop the sell price coloumn
input = df.drop('Sell Price($)', axis='columns')
input
# Out:
#                 Car Model  Mileage  Age(yrs)
# 0                  BMW X5    69000         6
# 1                  BMW X5    35000         3
# 2                  BMW X5    57000         5
# 3                  BMW X5    22500         2
# 4                  BMW X5    46000         4
# 5                 Audi A5    59000         5
# 6                 Audi A5    52000         5
# 7                 Audi A5    72000         6
# 8                 Audi A5    91000         8
# 9   Mercedez Benz C class    67000         6
# 10  Mercedez Benz C class    83000         7
# 11  Mercedez Benz C class    79000         7
# 12  Mercedez Benz C class    59000         5

# %%
target = df['Sell Price($)']
target
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
#convert input dat to dummy variabls
Le_CarModel =LabelEncoder()

# %%
#using the fit transform
input ["CarModel"] = Le_CarModel.fit_transform(input["Car Model"])
input
# Out:
#                 Car Model  Mileage  Age(yrs)  CarModel
# 0                  BMW X5    69000         6         1
# 1                  BMW X5    35000         3         1
# 2                  BMW X5    57000         5         1
# 3                  BMW X5    22500         2         1
# 4                  BMW X5    46000         4         1
# 5                 Audi A5    59000         5         0
# 6                 Audi A5    52000         5         0
# 7                 Audi A5    72000         6         0
# 8                 Audi A5    91000         8         0
# 9   Mercedez Benz C class    67000         6         2
# 10  Mercedez Benz C class    83000         7         2
# 11  Mercedez Benz C class    79000         7         2
# 12  Mercedez Benz C class    59000         5         2

# %%
#drop the initaila column
input_2 = input.drop('Car Model', axis='columns')
input_2
# Out:
#     Mileage  Age(yrs)  CarModel
# 0     69000         6         1
# 1     35000         3         1
# 2     57000         5         1
# 3     22500         2         1
# 4     46000         4         1
# 5     59000         5         0
# 6     52000         5         0
# 7     72000         6         0
# 8     91000         8         0
# 9     67000         6         2
# 10    83000         7         2
# 11    79000         7         2
# 12    59000         5         2

# %%
model = linear_model.LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(input_2, target)
# Out:
# LinearRegression()

# %%
#1) Predict price of a mercedez benz that is 4 yr old with mileage 45000
model.predict([[45000,4,2]])
# Out:
# array([33336.77218264])

# %%
#2) Predict price of a BMW X5 that is 7 yr old with mileage 86000
model.predict([[86000,7,1]])
# Out:
# array([16106.74127354])

# %%
#3) Tell me the score (accuracy) of your model. (Hint: use LinearRegression().score())
model.score(input_2, target)
# Out:
# 0.8719970367825953

# %%
#4) Predict price of a Audi A5 that is 3 yr old with mileage 30000
model.predict([[3000,3,0]])
# Out:
# array([48176.74039304])

# %%
#5) Predict price of a BMW X5 that is 2 yr old with mileage 40000
model.predict([[4000,2,1]])
# Out:
# array([48615.04380083])

# %%
#6)Predict the price of a mercedez benz tthat is 1 year old with mileage 20000.
model.predict([[2000,1,2]])
# Out:
# array([50288.69715114])

# %%
#7)Predict the price of a mercedez benz t that is 4 years old with mileage 40000.
model.predict([[4000,4,2]])
# Out:
# array([50219.88806372])
